# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.linspace(-10, 10, 20).reshape(-1, 1)

y = np.array([0 if i < 0 else 1 for i in X.flatten()])

m, n = X.shape

weights = np.zeros(n)
bias = 0

learning_rate = 0.1
iterations = 1000

def sigmoid(z):
    return 1 / (1 + np.exp(-z))

for _ in range(iterations):

    # Linear Equation
    z = np.dot(X, weights) + bias

    # Sigmoid Prediction
    predictions = sigmoid(z)

    # Gradients
    dw = (1 / m) * np.dot(X.T, (predictions - y))
    db = (1 / m) * np.sum(predictions - y)

    # Update
    weights = weights - learning_rate * dw
    bias = bias - learning_rate * db


plt.scatter(X, y, color='red', label='Data Points')

X_smooth = np.linspace(-10, 10, 100).reshape(-1, 1)

z_smooth = np.dot(X_smooth, weights) + bias
y_prob = sigmoid(z_smooth)

plt.plot(X_smooth, y_prob, color='blue', label='Sigmoid Curve')

plt.axhline(0.5, linestyle='--', color='gray', label='Threshold')

plt.xlabel("X")
plt.ylabel("Probability")
plt.title("Vectorized Logistic Regression")
plt.legend()

plt.show()

# %%
print(X.shape)
# Out:
# (20, 1)
